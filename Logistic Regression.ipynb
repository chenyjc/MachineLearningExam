# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

#load txt
data1=np.loadtxt('machine-learning-ex2/ex2/ex2data1.txt',delimiter=',')

X=data1[:,0:2]
y=data1[:,2]

posX=data1[y==1]
negX=data1[y==0]

matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.plot(posX[:,0],posX[:,1], 'k+',label='Admited')
ax.plot(negX[:,0],negX[:,1], 'yo',label='Not Admited')
ax.set_title('Exam1 Test Data')

legend = ax.legend(loc='upper right')

plt.show()
